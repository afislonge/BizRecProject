# %%
# !pip install pyspark
# Out:
# Requirement already satisfied: pyspark in /usr/local/lib/python3.10/dist-packages (3.5.3)
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)

# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, FloatType
from pyspark.sql import functions as F
from pyspark.sql.functions import broadcast
from pyspark.sql.functions import col, StringType
from pyspark.ml.feature import StringIndexer, VectorIndexer

# %%
# Create a Spark session
spark = SparkSession.builder.appName("rec").getOrCreate()

# %%
# Define schema for business_df
business_schema = StructType([
    StructField("business_id", StringType(), True),
    StructField("name", StringType(), True),
    StructField("address", StringType(), True),
    StructField("city", StringType(), True),
    StructField("state", StringType(), True),
    StructField("postal_code", StringType(), True),
    StructField("latitude", FloatType(), True),
    StructField("longitude", FloatType(), True),
    StructField("stars", FloatType(), True),
    StructField("review_count", IntegerType(), True),
    StructField("is_open", IntegerType(), True),
    StructField("attributes", StringType(), True),
    StructField("categories", StringType(), True),
    StructField("hours", StringType(), True)
])

# Load the Yelp datasets with explicit schema or schema inference hints
file_path = "/content/drive/MyDrive/yelp_business1.csv"
business_df = spark.read.csv(file_path, header=True, schema=business_schema)
business_df.show()
# Out:
# +--------------------+--------------------+--------------------+--------------+-----+-----------+---------+-----------+-----+------------+-------+----------+--------------------+-----+
# |         business_id|                name|             address|          city|state|postal_code| latitude|  longitude|stars|review_count|is_open|attributes|          categories|hours|
# +--------------------+--------------------+--------------------+--------------+-----+-----------+---------+-----------+-----+------------+-------+----------+--------------------+-----+
# |Pns2l4eNsfO8kk83d...|Abby Rappoport, L...|1616 Chapala St, ...| Santa Barbara|   CA|      93101|34.426678|  -119.7112|  5.0|           7|      0|      True|Doctors, Traditio...| NULL|
# |mpf3x-BjTdTEA3yCZ...|       The UPS Store|87 Grasso Plaza S...|        Affton|   MO|      63123|38.551125|  -90.33569|  3.0|          15|      1|      NULL|Shipping Centers,...| NULL|
# |tUFrWirKiKi_TAnsV...|              Target|5255 E Broadway Blvd|        Tucson|   AZ|      85711|32.223236|-110.880455|  3.5|          22|      0|     False|Department Stores...| NULL|
# |MTSW4McQd7CbVtyjq...|  St Honore Pastries|         935 Race St|  Philadelphia|   PA|      19107|39.955505|  -75.15556|  4.0|          80|      1|     False|Restaurants, Food...| NULL|
# |mWMc6_wTdE0EUBKIG...|Perkiomen Valley ...|       101 Walnut St|    Green Lane|   PA|      18054|40.338184|  -75.47166|  4.5|          13|      1|      NULL|Brewpubs, Breweri...| NULL|
# |CF33F8-E6oudUQ46H...|      Sonic Drive-In|       615 S Main St|  Ashland City|   TN|      37015|36.269592| -87.058945|  2.0|           6|      1|     False|Burgers, Fast Foo...| NULL|
# |n_0UpQx1hsNbnPUSl...|     Famous Footwear|8522 Eager Road, ...|     Brentwood|   MO|      63144|38.627693|  -90.34046|  2.5|          13|      1|      NULL|Sporting Goods, F...| NULL|
# |qkRM_2X51Yqxk3btl...|      Temple Beth-El|  400 Pasadena Ave S|St. Petersburg|   FL|      33707| 27.76659|  -82.73299|  3.5|           5|      1|      NULL|Synagogues, Relig...| NULL|
# |k0hlBqXX-Bt0vf1op...|Tsevi's Pub And G...|   8025 Mackenzie Rd|        Affton|   MO|      63123|38.565166|  -90.32108|  3.0|          19|      0|      NULL|Pubs, Restaurants...| NULL|
# |bBDDEgkFA1Otx9Lfe...|      Sonic Drive-In| 2312 Dickerson Pike|     Nashville|   TN|      37207|36.208103|  -86.76817|  1.5|          10|      1|     False|Ice Cream & Froze...| NULL|
# |UJsufbvfyfONHeWdv...|           Marshalls|21705 Village Lak...| Land O' Lakes|   FL|      34639|28.190458|  -82.45738|  3.5|           6|      1|      NULL|Department Stores...| NULL|
# |eEOYSgkmpB90uNA7l...|Vietnamese Food T...|                NULL|     Tampa Bay|   FL|      33602|27.955269|  -82.45632|  4.0|          10|      1|      NULL|Vietnamese, Food,...| NULL|
# |il_Ro8jwPlHresjw9...|             Denny's|        8901 US 31 S|  Indianapolis|   IN|      46227|39.637135|  -86.12722|  2.5|          28|      1|      NULL|American (Traditi...| NULL|
# |jaxMSoInw8Poo3XeM...|        Adams Dental|   15 N Missouri Ave|    Clearwater|   FL|      33755|27.966234| -82.787415|  5.0|          10|      1|      True|General Dentistry...| NULL|
# |0bPLkL0QhhPO5kt1_...|Zio's Italian Market|       2575 E Bay Dr|         Largo|   FL|      33771|27.916117|  -82.76046|  4.5|         100|      0|      NULL|Food, Delis, Ital...| NULL|
# |MUTTqe8uqyMdBl186...|            Tuna Bar|         205 Race St|  Philadelphia|   PA|      19106| 39.95395|  -75.14323|  4.0|         245|      1|      NULL|Sushi Bars, Resta...| NULL|
# |rBmpy_Y1UbBx8ggHl...|Arizona Truck Out...|     625 N Stone Ave|        Tucson|   AZ|      85705|32.229874| -110.97234|  4.5|          10|      1|     False|Automotive, Auto ...| NULL|
# |M0XSSHqrASOnhgbWD...|      Herb Import Co|        712 Adams St|   New Orleans|   LA|      70118|29.941467|  -90.12995|  4.0|           5|      1|      NULL|Vape Shops, Tobac...| NULL|
# |8wGISYjYkE2tSqn3c...|    Nifty Car Rental|     1241 Airline Dr|        Kenner|   LA|      70062|29.981182|  -90.25401|  3.5|          14|      1|      NULL|Automotive, Car R...| NULL|
# |ROeacJQwBeh05Rqg7...|                 BAP|       1224 South St|  Philadelphia|   PA|      19147|39.943222|  -75.16257|  4.5|         205|      1|      NULL| Korean, Restaurants| NULL|
# +--------------------+--------------------+--------------------+--------------+-----+-----------+---------+-----------+-----+------------+-------+----------+--------------------+-----+
# only showing top 20 rows

# %%
filtered_businesses = business_df.filter((F.col("review_count") >= 20) & (F.col("stars") >= 2))

# %%
filtered_businesses = filtered_businesses.withColumnRenamed("stars", "filtered_business_stars")

# %%
review_df = spark.read.csv("/content/drive/MyDrive/ProcessedCSV/final_review.csv", header=True, inferSchema=True)
columns_to_drop = review_df.columns
review_df = review_df.filter(F.col(columns_to_drop[0]) != review_df.first()[columns_to_drop[0]])
for col in columns_to_drop[1:]:
    review_df = review_df.filter(F.col(col) != review_df.first()[col])
review_df.show()
# Out:
# +--------------------+--------------------+--------------------+-----+------+-----+----+--------------------+----------+-------------------+
# |           review_id|             user_id|         business_id|stars|useful|funny|cool|                text|      date|               time|
# +--------------------+--------------------+--------------------+-----+------+-----+----+--------------------+----------+-------------------+
# |5Vy-AFz0Ek1FF6s1a...|tbI8YO0O51Mrm_yIi...|4QjOsH83KEcjen94P...|    4|     8|    5|   9|This review is fo...|2016-03-07|2024-11-03 22:17:05|
# |HsthKXBHUDCDOUH1z...|rytAuNSEgYf_xqkKZ...|j-qtdD55OLfSqfsWu...|    4|     1|    1|   0|Somehow we got ca...|2015-08-31|2024-11-03 20:11:08|
# |zg5iA1-3eoozePgAS...|Q8V8JWWQNrpvD2bXC...|9cybDNxJ7cyNVkmwm...|    5|     0|    1|   0|Huge fan of this ...|2013-05-12|2024-11-03 01:44:00|
# |FYj6Tx_Ft4VvkGFgD...|2lFni8ituUYceQJPx...|Iw8uqNPxviwcgxtru...|    1|     7|    5|   3|Things you should...|2010-12-05|2024-11-03 09:18:11|
# |vmaErJz1v5tr0Vybf...|HkbiKPFKaJPdLwPQG...|ixAWNAUrA7JjwvMJz...|    4|     2|    1|   1|Was informed by d...|2015-05-29|2024-11-03 23:20:05|
# |JYJ_EsFX8DQAvlTYx...|9Ba1QLi-_n5ijOUYp...|-bUlpYP74Ei8VkSGp...|    1|     2|    1|   0|Someone from this...|2015-03-23|2024-11-03 14:12:06|
# |eibqXCayeqBuRIlBL...|w-hg9fO4EYJTffKbW...|KnsY8rh5tigp5t6Wp...|    4|     2|    4|   1|Whole Foods is li...|2011-08-29|2024-11-03 18:14:47|
# |L9YHX9CVevipN49BN...|xMGWttm6V-cvP3V2f...|HP03UxUpfwic04tBu...|    2|     1|    1|   1|Ordered delivery....|2018-06-21|2024-11-03 01:57:19|
# |Y7Tk2c14VsaO_nHvR...|I99z9bNf82ESzBJoY...|dKAu4j6GskdIvyiBy...|    1|     6|    2|   0|Update: I changed...|2012-06-30|2024-11-03 21:07:00|
# |T_iM9qQ_JF97ZNeod...|HPvG3bwrp1U1VRafj...|JLumGKzGu9kqGTdwY...|    2|     0|    1|   0|This place has po...|2011-09-29|2024-11-03 01:12:11|
# |ZnA9BxZQA8UAqzbi5...|ooLcX8Ey8fMTB81tT...|CTvHlHQ4jzRO8gkkl...|    5|     3|    1|   0|By far the most a...|2014-01-03|2024-11-03 00:44:51|
# |-88EuW9LAa3UUJ1pi...|3tAW8YObI7gpFggaz...|1YflE3DkiCZGgLnf3...|    5|    14|    2|   8|I live just South...|2014-09-29|2024-11-03 13:51:41|
# |lVHdykXMARM_Nqfup...|kzDzdbPupHiglDzs9...|IvAa7PvfOYl0xRML5...|    4|    12|    4|   7|People will fight...|2017-05-15|2024-11-03 02:22:14|
# |4zHPPk6HtTtbfExrM...|ApwWZBmsF9_gCwam6...|TunmRrfZb7bt53T6H...|    1|     2|    5|   1|DO NOT ORDER DELI...|2015-02-21|2024-11-03 01:52:19|
# |BjxWsDxpO8YPV-El9...|OI8taAco53qGwEzbE...|dL8yaO7NtWpBar8CH...|    4|     6|    2|   3|Wandered in here ...|2011-07-04|2024-11-03 15:45:27|
# |RiydWL4uWz2W3F0xI...|8O5tGAz_LFuX3JTim...|NgCDBhNiVpUDwvpi0...|    2|     1|    1|   0|There are way too...|2011-07-07|2024-11-03 18:47:28|
# |2wCabGwTJKPhiPZpb...|6Q8dQGr_DBKcmQ1aX...|qjSU3SL8CaGfmOL_B...|    2|     1|    2|   0|The theater smell...|2014-09-29|2024-11-03 13:47:40|
# |kdD6T52KAsdv-m_Mu...|zK9xI4tX-Qk43pfc4...|z8YngIHNZI0A05DeM...|    1|     0|    1|   0|Well let's start ...|2016-11-24|2024-11-03 12:58:55|
# |8t-tX1V56l9QKPOA3...|VBxscaJ2Q3YH4Vs8W...|elnmOdMKGQvAF9FoV...|    5|     0|    1|   1|Great bikes. Very...|2014-12-01|2024-11-03 18:20:41|
# |cfFKGABwOJYSsxkiR...|f302ihzVqr3CC4nBo...|3cfo_0_GjpJ2mWRYk...|    4|     0|    1|   0|Nice hotel if you...|2017-09-22|2024-11-03 05:19:32|
# +--------------------+--------------------+--------------------+-----+------+-----+----+--------------------+----------+-------------------+
# only showing top 20 rows

# %%
import pyspark.sql.functions as F

filtered_reviews = review_df.filter((F.col("stars") >= 2) )

# %%
# Perform the join if both DataFrames contain data
if filtered_reviews.count() > 0 and filtered_businesses.count() > 0:
    joined_df = filtered_reviews.join(filtered_businesses, on="business_id", how="inner")
    joined_df.show(10)
else:
    print("One or both DataFrames are empty, cannot perform join.")
# Out:
# +--------------------+--------------------+--------------------+-----+------+-----+----+--------------------+----------+-------------------+--------------------+--------------------+------------+-----+-----------+---------+-----------+-----------------------+------------+-------+----------+--------------------+-----+
# |         business_id|           review_id|             user_id|stars|useful|funny|cool|                text|      date|               time|                name|             address|        city|state|postal_code| latitude|  longitude|filtered_business_stars|review_count|is_open|attributes|          categories|hours|
# +--------------------+--------------------+--------------------+-----+------+-----+----+--------------------+----------+-------------------+--------------------+--------------------+------------+-----+-----------+---------+-----------+-----------------------+------------+-------+----------+--------------------+-----+
# |--9osgUCSDUWUkoTL...|ItZuxtEiSOMDd0cRJ...|h70Izpu92o8LRwGt8...|    5|     1|    1|   0|We did Santa's Na...|2021-03-29|2024-11-03 16:23:21|    Will You Escape?|    2577 N First Ave|      Tucson|   AZ|      85719|32.253677| -110.96177|                    5.0|          29|      1|      True|Active Life, Chal...| NULL|
# |--9osgUCSDUWUkoTL...|tyZ4pBzZdrm70vRWe...|DdPEm9nl_5zxrzGNa...|    5|     0|    1|   0|1st time ever bee...|2021-01-05|2024-11-03 19:53:36|    Will You Escape?|    2577 N First Ave|      Tucson|   AZ|      85719|32.253677| -110.96177|                    5.0|          29|      1|      True|Active Life, Chal...| NULL|
# |--epgcb7xHGuJ-4PU...|w5AiH-OIoryeNSZ-u...|6woTWCjHDMEjQclni...|    5|     2|    1|   0|Bagels are pretty...|2013-01-15|2024-11-03 05:53:08|     Manhattan Bagel|       200 York Road|Willow Grove|   PA|      19090|40.145054| -75.116295|                    3.0|          34|      1|      NULL|Restaurants, Food...| NULL|
# |--epgcb7xHGuJ-4PU...|q2erWQADaQliZw1vG...|bQduRxvheoA9xp4qM...|    2|     1|    2|   0|This place is the...|2017-01-01|2024-11-03 16:02:00|     Manhattan Bagel|       200 York Road|Willow Grove|   PA|      19090|40.145054| -75.116295|                    3.0|          34|      1|      NULL|Restaurants, Food...| NULL|
# |--epgcb7xHGuJ-4PU...|-YPSb7opc8nTWPumW...|-VmiK2zFPDvDFYeZX...|    5|     0|    1|   0|This place is alm...|2013-03-24|2024-11-03 04:56:48|     Manhattan Bagel|       200 York Road|Willow Grove|   PA|      19090|40.145054| -75.116295|                    3.0|          34|      1|      NULL|Restaurants, Food...| NULL|
# |--epgcb7xHGuJ-4PU...|fNpJqt0sYOoiwxpP1...|eqFga5ggF4kr_lkte...|    4|     2|    1|   0|Called in an orde...|2021-12-01|2024-11-03 15:16:00|     Manhattan Bagel|       200 York Road|Willow Grove|   PA|      19090|40.145054| -75.116295|                    3.0|          34|      1|      NULL|Restaurants, Food...| NULL|
# |-02xFuruu85XmDn2x...|0_-8nKLlT25m0tPed...|qe9cM4t63vKLhFaqd...|    5|     0|    1|   1|Super friendly st...|2014-02-27|2024-11-03 19:04:55|Family Vision Center|7475 E Tanque Ver...|      Tucson|   AZ|      85715|32.251038|-110.833176|                    4.5|         109|      1|      True|Shopping, Ophthal...| NULL|
# |-02xFuruu85XmDn2x...|DdOsD5sk1cmGBUIv0...|J525z_uXY-57qZvNa...|    5|     1|    1|   0|Dr Curtis is exce...|2012-08-10|2024-11-03 22:08:04|Family Vision Center|7475 E Tanque Ver...|      Tucson|   AZ|      85715|32.251038|-110.833176|                    4.5|         109|      1|      True|Shopping, Ophthal...| NULL|
# |-02xFuruu85XmDn2x...|2ueTH_vgkq0IrjjtH...|m8ALOcSqmMRPMzBnL...|    2|     5|    1|   0|My wife and I wer...|2013-03-21|2024-11-03 23:48:47|Family Vision Center|7475 E Tanque Ver...|      Tucson|   AZ|      85715|32.251038|-110.833176|                    4.5|         109|      1|      True|Shopping, Ophthal...| NULL|
# |-02xFuruu85XmDn2x...|tWy3gT4G_o9EpWNe7...|DdPEm9nl_5zxrzGNa...|    5|     0|    1|   0|Everyone is so fr...|2021-03-12|2024-11-03 18:54:43|Family Vision Center|7475 E Tanque Ver...|      Tucson|   AZ|      85715|32.251038|-110.833176|                    4.5|         109|      1|      True|Shopping, Ophthal...| NULL|
# +--------------------+--------------------+--------------------+-----+------+-----+----+--------------------+----------+-------------------+--------------------+--------------------+------------+-----+-----------+---------+-----------+-----------------------+------------+-------+----------+--------------------+-----+
# only showing top 10 rows

# %%
filtered_reviews = filtered_reviews.withColumnRenamed("stars", "filtered_review_stars")

# %%
joined_df1 = filtered_reviews.join(broadcast(filtered_businesses), on="business_id", how="inner")

# %%
final_df = joined_df1.select(
    col("user_id").cast(StringType()),
    col("business_id").cast(StringType()),
    col("filtered_review_stars").cast(FloatType())  # Choose which column to use
)

# %%
# Create StringIndexer objects for user_id and business_id
user_indexer = StringIndexer(inputCol="user_id", outputCol="user_id_indexed")
business_indexer = StringIndexer(inputCol="business_id", outputCol="business_id_indexed")

# Fit the indexers and transform the DataFrame
indexed_df = user_indexer.fit(final_df).transform(final_df)
indexed_df = business_indexer.fit(indexed_df).transform(indexed_df)

# %%
from pyspark.sql.functions import collect_list

# Extract the unique business IDs and their corresponding indexed values
business_id_mapping_df = indexed_df.select('business_id', 'business_id_indexed').distinct()

# Convert the DataFrame to a list of tuples
business_id_mapping_list = business_id_mapping_df.collect()

# Create a dictionary from the list of tuples
business_id_mapping_dict = {row['business_id']: row['business_id_indexed'] for row in business_id_mapping_list}

# Print the dictionary
print(business_id_mapping_dict)
# Out:
# {'NHb6QTrJOnyIj-Zd0fYzFg': 198.0, 'n5TNfoXg1i8wX5R3iY4WUA': 7514.0, 'PHqeN9MKNA_TfIUfmpBeRw': 9853.0, 'AOCwwM2f1X4-Ge4Ilv-X4g': 45963.0, '1rkmbnMjrYBM-hOckvnNFw': 15347.0, 'CUWituEeIX3xA0xU7X82Ow': 7109.0, 'XHxAIQR-QAz6j1RMaz_J1A': 19254.0, '6bpM6wCmdp6qZGTQbiR3-A': 30193.0, 'vI-2mPYOgfix5LcaqDOy_g': 11747.0, '7qL4Ech8XKYNvZb_JuP-Sw': 9572.0, 'lnEeMas32ddqNn06jOUGgQ': 42426.0, 'lPperLiGwJVEr9n8LfGZ5g': 13034.0, 'mmnneqm5rY6MNwF--uScYw': 34603.0, '2hIA-ubXzEoz4N5xQU1qHw': 17788.0, '_l2fthwLTqgLNM6budicQA': 33226.0, 'kyRUZEZThKotuabJQfuXYA': 3645.0, 'NnW-Ju9vAh4WRrWaNVPHBQ': 47936.0, 'IvAa7PvfOYl0xRML5W3ebg': 604.0, '8Vu3Iagcby29cZIijIk4Ng': 5409.0, 'VVMAvAVRpoVk6bd4avvYGw': 32668.0, 'vQQpyrhgqF5El4a_hNDdaA': 24142.0, 'JAaiz9eoJ3BSyQx-pVuX_Q': 15974.0, 'JJSxd_WYEP4qYaHPG_tQ7w': 15977.0, 'uCR5u51sWF2E9OByxo2Olw': 43518.0, 'gECyO9S9P3wQEgVZIjR49g': 33904.0, 'VU_IdfezeFylMEeBuJGzkQ': 49037.0, 'kokdzLxHKyxfNv5SEz0klw': 42316.0, 'bAAN8_3lDA0baaYQ2bbK1w': 41049.0, 'CNDFASo4BpgATitxqUfkLA': 37731.0, 'wjOHfRYCwddZ3Ri_AvScaQ': 53071.0, 'AgcJCv6R9d40ByHZrDJ62A': 2695.0, 'IDjYyBrPW5C2CT9mXsyuBA': 3080.0, 'A5e2SU0SOAI3wJWm_YTxCA': 3759.0, 'uJtL2WqZq3J262QneKWjrg': 35406.0, '__93GWaEEcUf9TSyyJbkmQ': 49794.0, '2S3Es3yR29DI7DHWoIgaxw': 24722.0, 'WLYZjUusZ9kwwWvgCLtlCw': 16457.0, '8-B9Q7Wu3Z0RxYuz0HdlmA': 25165.0, '2g1ZiT6cM1NC4nJ8xS6EGg': 11915.0, '8NeQKx9kYZIQclGPj7ynoA': 25204.0, '0IM3PqePeExMJ0XzUwSvhw': 17667.0, '0RxW0oN1s4zgNh6uiWVPZQ': 10534.0, 'CGNccuDSFO9ZtqhQ46msOA': 3513.0, 'tMsQnjwF4T8_a_JbfbaCFw': 13231.0, 'hHCGmb01EGFstumCsd4-VA': 14698.0, 'Aa6V6ywigO05G2uk3hkIxA': 25377.0, 'IAuLHyV0o-BZ04oyIp671w': 31332.0, 'KN0eP1JyvREOyNfs4Ujavw': 21876.0, 'vRpLLFKEy6MDkNxZ82Zr3Q': 52866.0, 'G374erxXpE7ArbxJ4kUnSA': 18452.0, 'rRtVevRah3xYk4nunzzajA': 23873.0, '9gOB2Tqc_LtvSRDxviFlHA': 12083.0, '3z6NoBqJ1JbVId7vxRcBfw': 10604.0, 'DcBLYSvOuWcNReolRVr12A': 45.0, 'BaWVwChTW_MqkKru_WZp3g': 2255.0, 'tKRWRAeEI-epyxAixU2vHg': 20323.0, 'y4fP_nGybK3io_TewdhqpA': 29216.0, 'lw3p_2nYhzsgRLIMx1mn4w': 17095.0, '2CvDC4izZ55VHSqk5N8cFA': 3029.0, '8R-ObAoppiDpucPYjyncUw': 9583.0, 'X_OnAUXVGHjyWP9zoPVLTA': 2176.0, '2P-pvj_jo0SxNe6jih6sOA': 24721.0, 'pRqLUBx3LPiKZ5PKU_fwdg': 34872.0, 'V6wr6ibKSuPm9x5PMZOufA': 16422.0, 'JsUWxd9KwOvuq_Im8DZfEw': 13948.0, 'q_1xjztlLeeYo12GBsuZXw': 9292.0, '5WXHGOYSi979NOi1oj2atA': 7751.0, 'f_QxYk7vE2rjn8u7qQkTbQ': 50642.0, 'POwyAA0vf4PvWe1L8Oc3Eg': 5097.0, '9msyhbpQ5visk8bNlFdaVQ': 30505.0, 'xlMQBBt9wrtahdqiRDcVSg': 143.0, 'UFCN0bYdHroPKu6KV5CJqg': 365.0, 'ijnCPsMfWWcxGlzwOzUxIg': 16971.0, '8lkst0bYgdXr8CRQv6NloA': 3500.0, 'XtsC6TtjGb9TnDQ5voUxuA': 40480.0, 'g1ilXJRmG8GPQvm9_-izsw': 23212.0, 'c1xuic_qvUfSIr-if6nSUQ': 11352.0, 'hg-2O1MpZ24DhhR4WWofSw': 11457.0, '52q3_FQ5uX43IayrQS7znQ': 11973.0, '_A_o8TE3r7VpIzinOffy0A': 22815.0, 'ThpNtCxktDMcnfLJR5fTNA': 19106.0, '8CbJAKgVEALPbYcQTzhkvA': 13647.0, 'bPiBAhovI1WCApbVnSICcg': 16692.0, 'TqezXFPh-f2cqIgkMvzHmQ': 7292.0, 'rmvEN4p8to8hx7o7lo8Xlg': 28710.0, 'G34TWxDltxUBelSqVhpV2g': 15870.0, 'B1uf_53BMDEjhCCyjjmaKg': 12114.0, 'Q9FuyltF8hyy1eNGr-HD_A': 39471.0, 'OCzo8T-76iJ_QVB2UX5SEQ': 265.0, 'JzQsy7_G0p-UZGYFMCEHvQ': 1954.0, 'BZU9iLoVPeBzUlp1s8756A': 3058.0, 'hqqBYeQQ_c2FMvgGKrr59A': 4844.0, 'ADe114o7Z4vb1O6HkM6YEA': 3053.0, 'kdwh4bEAb9uYpSP0U7HSjw': 6233.0, 'M_Jr18nhOCBq462yQw12JQ': 31795.0, 'EC20rN7JtmAPIxcw3MTzcQ': 3522.0, '5V1Bo1GZhPaR75pvnrvdAA': 30078.0, '8-ZExybRuyyXZf6aESgc3g': 2534.0, 'I0x83KzaK-3ssNGa5SknhQ': 21723.0, 'U538QRB4bTY2V4rwXRT9ug': 22474.0, 'EX4_wdtB3mnAVpd8n7NsWA': 30981.0, 'BA7tMgnXFAWE8M5CMrZ4jA': 37582.0, '2CTROlVg82eGFAHPxqjAqA': 29722.0, '4BKKBx50oZaEczazjZ1ZEQ': 36720.0, 'CmmmUb9s0k0OPb6wAGKBqA': 37786.0, 'arhZ44NOTAA_nb_tfmKn1Q': 33345.0, 'MymLJ21yIMrotlJiXbd6Gg': 10993.0, 'P2XJbQZmf1zvWp9L_THdjQ': 2907.0, 'WVokxjYmNVU-AsFNV3loPw': 27023.0, 'Nvy1jETQItFjG0oyjpGk7w': 6584.0, 'oipTcwrQb6jQy0VrqpFumQ': 10298.0, '3VTJhl4m1o380EfWgXmZbg': 24802.0, '5WrrZsSg2_XA1EJQq5LGAQ': 8574.0, 'C8whV2z3YVNH8GvSZTKgOQ': 37708.0, 'YEKYKjW8KkAXHytC8d1xYg': 19291.0, 'hvi7FOP6LN8dMTG ...

# %%
def find_business_key(business_id_mapping_dict, value):
  """
  Finds the business key corresponding to a value in the dictionary.

  Args:
    business_id_mapping_dict: The dictionary mapping business IDs to indexed values.
    value: The value to search for.

  Returns:
    The business key (business_id) corresponding to the value, or None if not found.
  """
  for business_id, indexed_value in business_id_mapping_dict.items():
    if indexed_value == value:
      return business_id
  return None


# Example usage:
value_to_find = 2590.0  # Replace with the value to find
business_id = find_business_key(business_id_mapping_dict, value_to_find)
if business_id:
  print(f"The business ID for value {value_to_find} is: {business_id}")
else:
  print(f"No business ID found for value {value_to_find}") #
# Out:
# The business ID for value 2590.0 is: W57360g1e7xMGerm7wPW0Q

# %%
# writing the json

import json
# from google.colab import drive
# drive.mount('/content/drive')


# Specify the file path
file_path = "/content/drive/MyDrive/Models/businessmapping.json"

# Write the dictionary to the JSON file
with open(file_path, 'w') as f:
  json.dump(business_id_mapping_dict, f)

print(f"Dictionary written to {file_path}")
# Out:
# Dictionary written to /content/drive/MyDrive/Models/businessmapping.json

# %%
# loading the saved model

import pickle

# Load the saved model from the specified path
with open('/content/drive/MyDrive/Models/random_forest_model2.pkl', 'rb') as f:
  loaded_model = pickle.load(f)

# %%
import os
import pandas as pd

file_path = '/content/drive/MyDrive/ProcessedCSV/features_df.csv'

# Get a list of all part files in the directory
part_files = [os.path.join(file_path, f) for f in os.listdir(file_path) if f.endswith('.csv')]

# Concatenate all part files into a single DataFrame
df = pd.concat([pd.read_csv(f) for f in part_files], ignore_index=True)


print(df.head())  # Display the first few rows
# Out:
#               business_id                                     name  \
# 0  NQhyMw8SOU1HB-V9X52CTg  Champion Chevrolet - Service Department
# 1  2y_CdkxEOJEJGyJApfCYpA      Rode's Fireside Restaurant & Tavern
# 2  8PNKnlnJg6snf-HUgFaNIw                             U Dirty Dawg
# 3  sk2lZI4zmuGAccd3DLCnBw                Boyd Hill Nature Preserve
# 4  83IeQHroXEctmMpK19TJKw           The Richel D'Ambra Spa & Salon
#
#                    address              city state postal_code   latitude  \
# 0           800 Kietzke Ln              Reno    NV       89502  39.518223
# 1            533 Kings Hwy      Woolwich Twp    NJ       08085  39.753252
# 2      2435 S State Rd 135         Greenwood    IN       46143  39.579628
# 3  1101 Country Club Way S  Saint Petersburg    FL       33705  27.725123
# 4    10 Avenue of the Arts      Philadelphia    PA       19102  39.951298
#
#     longitude  business_stars  review_count  is_open  \
# 0 -119.787714             3.0            45        1
# 1  -75.302486             3.5           104        1
# 2  -86.158564             4.0            32        1
# 3  -82.650080             5.0            33        1
# 4  -75.164270             3.5            65        1
#
#                                           categories  avg_sentiment  \
# 0                            Automotive, Auto Repair       0.040079
# 1                Restaurants, American (Traditional)       0.315741
# 2  Pet Sitting, Pet Training, Pet Groomers, Pets,...       0.675000
# 3                         Active Life, Parks, Hiking       0.187302
# 4               Hair Salons, Day Spas, Beauty & Spas       0.462337
#
#    avg_review_stars  total_reviews  total_checkin_count
# 0          1.000000              1                    8
# 1          4.000000              1                  110
# 2          4.000000              1                   23
# 3          4.000000              1                  115
# 4          4.666667              3                   41

# %%
feature_columns = ["business_stars", "review_count", "avg_sentiment", "avg_review_stars", "total_reviews", "total_checkin_count"]


def predict_success_for_business_ids(business_ids, model, features_df, feature_columns):
    # Filter the dataset for the provided business IDs
    input_data = features_df[features_df["business_id"].isin(business_ids)]
    X_input = input_data[feature_columns]

    # Predict success probability
    success_probabilities = model.predict(X_input)

    # Create a DataFrame to display results
    result_df = pd.DataFrame({
        "business_id": input_data["business_id"],
        "success_probability": success_probabilities*10000
    })

    return result_df

# Example usage
business_ids_to_predict = ['IZAMcBLQ365GsrgonoM79w']
success_probabilities = predict_success_for_business_ids(business_ids_to_predict, loaded_model, df, feature_columns)

print("Predicted Success Probabilities:")
print(success_probabilities)
# Out:
# Predicted Success Probabilities:
#                   business_id  success_probability
# 1946   W57360g1e7xMGerm7wPW0Q           189.433630
# 9016   R46XVcmUzy8qeerHyZQtEg           127.708652
# 11495  IZAMcBLQ365GsrgonoM79w            34.489153
# 21795  MnjCw3oaM0Hq39bjONDU0Q           102.687166
# 32206  GAXuzDNbzfZbtZYxqrdHnw           134.529491

# %%
from sklearn.preprocessing import MinMaxScaler
import pandas as pd

# Define feature columns
feature_columns = ["business_stars", "review_count", "avg_sentiment", "avg_review_stars", "total_reviews", "total_checkin_count"]

def predict_success_for_business_ids(business_ids, model, features_df, feature_columns):
    # Filter the dataset for the provided business IDs
    input_data = features_df[features_df["business_id"].isin(business_ids)]
    X_input = input_data[feature_columns]

    # Predict success values (not necessarily probabilities yet)
    success_values = model.predict(X_input).reshape(-1, 1)

    # Use Min-Max Scaler to transform values into a probability range (0-100%)
    scaler = MinMaxScaler(feature_range=(0, 100))
    success_probabilities = scaler.fit_transform(success_values).flatten()

    # Create a DataFrame to display results
    result_df = pd.DataFrame({
        "business_id": input_data["business_id"].values,
        "success_probability": success_probabilities
    })

    return result_df

# Example usage
business_ids_to_predict = ['MnjCw3oaM0Hq39bjONDU0Q','R46XVcmUzy8qeerHyZQtEg', 'GAXuzDNbzfZbtZYxqrdHnw', 'IZAMcBLQ365GsrgonoM79w', 'W57360g1e7xMGerm7wPW0Q']
success_probabilities = predict_success_for_business_ids(business_ids_to_predict, loaded_model, df, feature_columns)

print("Predicted Success Probabilities:")
print(success_probabilities)
# Out:
# Predicted Success Probabilities:
#               business_id  success_probability
# 0  W57360g1e7xMGerm7wPW0Q           100.000000
# 1  R46XVcmUzy8qeerHyZQtEg            60.163164
# 2  IZAMcBLQ365GsrgonoM79w             0.000000
# 3  MnjCw3oaM0Hq39bjONDU0Q            44.014485
# 4  GAXuzDNbzfZbtZYxqrdHnw            64.565282
